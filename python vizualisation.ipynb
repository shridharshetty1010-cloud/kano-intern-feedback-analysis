# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\SAMAH\\Downloads\\Year_wise_financial_performance_of_bmtc.csv")

# %%
data
# Out:
#    Sl No                           Factors  \
# 0    VII                   Working Results
# 1      1  Traffic Revenue  (Rs. in Lakhs.)
# 2      a           Through Sale of Tickets
# 3      b                      Monthly pass
# 4      c                        Daily pass
# 5      d                      Student pass
# 6      e                            Others
# 7    NaN                             Total
# 8      2     Other Revenue ( Rs. in lakhs)
# 9      a          Government Reimbursement
# 10     b                    Advertisements
# 11     c      Rent from Commercial outlets
# 12     d           Sale of scrap materials
# 13     e            Sale of scrap vehicles
# 14     f                            Others
# 15   NaN                             Total
# 16     3       Gross Revenue (Rs.in lakhs)
# 17     4          EPKM on Traffic Revenue
# 18   NaN                        (in paise)
# 19   NaN                          % Growth
# 20     5            EPKM on Gross Revenue
# ...

# %%
data.head()
# Out:
#   Sl No                           Factors  \
# 0   VII                   Working Results
# 1     1  Traffic Revenue  (Rs. in Lakhs.)
# 2     a           Through Sale of Tickets
# 3     b                      Monthly pass
# 4     c                        Daily pass
#
#    1997-98 (After  bifurcation w.e.f. 15-08-97)    2015-16    2016-17 2017-18  \
# 0                                           NaN        NaN        NaN     NaN
# 1                                           NaN        NaN        NaN     NaN
# 2                                           NaN  113371.82  106769.85  109928
# 3                                           NaN   47655.64   45574.44   43355
# 4                                           NaN   20422.87   15654.61   15322
#
#      2018-19    2019-20 2020-21 (Estimated
# 0        NaN        NaN                NaN
# 1        NaN        NaN                NaN
# 2  121350.16  122498.91              45162
# 3   41415.03   32043.31              13774
# ...

# %%
data.head(14)
# Out:
#    Sl No                           Factors  \
# 0    VII                   Working Results
# 1      1  Traffic Revenue  (Rs. in Lakhs.)
# 2      a           Through Sale of Tickets
# 3      b                      Monthly pass
# 4      c                        Daily pass
# 5      d                      Student pass
# 6      e                            Others
# 7    NaN                             Total
# 8      2     Other Revenue ( Rs. in lakhs)
# 9      a          Government Reimbursement
# 10     b                    Advertisements
# 11     c      Rent from Commercial outlets
# 12     d           Sale of scrap materials
# 13     e            Sale of scrap vehicles
#
#     1997-98 (After  bifurcation w.e.f. 15-08-97)    2015-16    2016-17  \
# 0                                            NaN        NaN        NaN
# 1                                            NaN        NaN        NaN
# 2                                            NaN  113371.82  106769.85
# ...

# %%
data.tail(6)
# Out:
#    Sl No                     Factors  \
# 30     9    Margin on Gross Revenue
# 31   NaN               (Rs in lakhs)
# 32    10  Margin on Traffic Revenue
# 33   NaN                  (in paise)
# 34    11    Margin on Gross Revenue
# 35   NaN                  (in paise)
#
#     1997-98 (After  bifurcation w.e.f. 15-08-97)     2015-16      2016-17  \
# 30                                       -781.74  (+)1372.66  (-)26091.01
# 31                                           NaN         NaN          NaN
# 32                                       -204.60    (-)616.9    (-)1418.6
# 33                                           NaN         NaN          NaN
# 34                                        -85.00     (+)30.7     (-)620.5
# 35                                           NaN         NaN          NaN
#
#         2017-18      2018-19      2019-20 2020-21 (Estimated
# 30  (-)21761.49  (-)34948.74  (-)54934.00        (-)16419.98
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Sl No                                         23 non-null     object
#  1   Factors                                       36 non-null     object
#  2   1997-98 (After  bifurcation w.e.f. 15-08-97)  17 non-null     float64
#  3   2015-16                                       26 non-null     object
#  4   2016-17                                       26 non-null     object
#  5   2017-18                                       26 non-null     object
#  6   2018-19                                       26 non-null     object
#  7   2019-20                                       26 non-null     object
#  8   2020-21 (Estimated                            26 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 2.7+ KB

# %%
data.describe()
# Out:
#        1997-98 (After  bifurcation w.e.f. 15-08-97)
# count                                     17.000000
# mean                                    2236.311765
# std                                     4578.604721
# min                                    -1881.050000
# 25%                                       18.280000
# 50%                                       73.460000
# 75%                                     1279.600000
# max                                    12543.220000

# %% [markdown]
# ## cleaning the dataset

# %%
data.isnull().sum()
# Out:
# Sl No                                           13
# Factors                                          0
# 1997-98 (After  bifurcation w.e.f. 15-08-97)    19
# 2015-16                                         10
# 2016-17                                         10
# 2017-18                                         10
# 2018-19                                         10
# 2019-20                                         10
# 2020-21 (Estimated                              10
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.duplicated()
# Out:
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 16    False
# 17    False
# 20    False
# 23    False
# 26    False
# 28    False
# 30    False
# 32    False
# 34    False
# dtype: bool

# %%
data.drop_duplicates(inplace = True)

# %%
data
# Out:
#    Sl No                       Factors  \
# 9      a      Government Reimbursement
# 10     b                Advertisements
# 11     c  Rent from Commercial outlets
# 12     d       Sale of scrap materials
# 13     e        Sale of scrap vehicles
# 14     f                        Others
# 16     3   Gross Revenue (Rs.in lakhs)
# 17     4      EPKM on Traffic Revenue
# 20     5        EPKM on Gross Revenue
# 23     6     Total Cost of operations
# 26     7               CPKM (in paise)
# 28     8    Margin on Traffic Revenue
# 30     9      Margin on Gross Revenue
# 32    10    Margin on Traffic Revenue
# 34    11      Margin on Gross Revenue
#
#     1997-98 (After  bifurcation w.e.f. 15-08-97)      2015-16      2016-17  \
# 9                                         910.00     19520.97     21095.39
# 10                                         20.94      1209.67      1399.63
# 11                                         18.28      5755.08      5941.03
# ...

# %% [markdown]
# # visualisation

# %%
data.plot()
plt.show()

# %%
data.plot(kind = 'scatter', x = 'Factors', y = '2015-16')

plt.show()

# %%
data["1997-98 (After  bifurcation w.e.f. 15-08-97)"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
